# %%
source
# Out:
# Widget()

# %%
target
# Out:
# Widget()

# %%
w.jslink((source, 'value'), (target, 'value'))
# Out:
# Link(source=(Counter(value=1), 'value'), target=(Counter(value=2), 'value'))
